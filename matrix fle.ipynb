# %%
import numpy as np
import matplotlib.pyplot as plt

# Load or create the 4x4x4 matrix
matrix_4x4x4 = np.load('matrix_4x4x4.npy')  # Replace with the actual file path if needed

# Plot each 2D slice
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i in range(4):
    ax = axes[i]
    ax.imshow(matrix_4x4x4[i], cmap='viridis', interpolation='nearest')
    ax.set_title(f"Slice {i+1}")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from tqdm import tqdm  # For progress bars

# Simulate loading process with a progress bar
print("Loading matrix data...")
for _ in tqdm(range(10), desc="Processing"):
    sleep(0.1)  # Simulates processing/loading time

# Load or create a 4x4x4 matrix
matrix_4x4x4 = np.load('D:/matrix.npy')  # Replace with your actual matrix file path

# Define names for rows, columns, and slices
row_names = ["Row A", "Row B", "Row C", "Row D"]
col_names = ["Col 1", "Col 2", "Col 3", "Col 4"]
slice_names = ["Slice Alpha", "Slice Beta", "Slice Gamma", "Slice Delta"]

# Display matrix structure
print("\nMatrix Loaded!")
print("Matrix Shape:", matrix_4x4x4.shape)
print("\nMatrix Dimensions:", matrix_4x4x4.ndim)
print("\nMatrix Slices with Names:")

# Print each slice with labeled rows and columns
for i, slice_name in enumerate(slice_names):
    print(f"\n{slice_name}:\n")
    print("   " + "  ".join(col_names))
    for row_name, row_data in zip(row_names, matrix_4x4x4[i]):
        print(row_name, row_data)

# Simulate loading visualization with a progress bar
print("\nGenerating visualizations...")
for _ in tqdm(range(10), desc="Rendering"):
    sleep(0.1)  # Simulates rendering time

# Annotated Visualization
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
for slice_idx in range(matrix_4x4x4.shape[0]):
    ax = axes[slice_idx]
    cax = ax.imshow(matrix_4x4x4[slice_idx], cmap="viridis", interpolation="nearest")
    ax.set_title(f"{slice_names[slice_idx]} (Layer {slice_idx+1})")
    ax.set_xlabel("Columns")
    ax.set_ylabel("Rows")
    ax.set_xticks(range(matrix_4x4x4.shape[2]))
    ax.set_xticklabels(col_names)
    ax.set_yticks(range(matrix_4x4x4.shape[1]))
    ax.set_yticklabels(row_names)
    plt.colorbar(cax, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from tqdm import tqdm  # For progress bars

# Simulate loading process with a progress bar
print("Loading matrix data...")
for _ in tqdm(range(10), desc="Processing"):
    sleep(0.1)  # Simulates processing/loading time

# Load or create a 4x4x4 matrix
matrix_4x4x4 = np.load('D:/matrix.npy')  # Replace with your actual matrix file path

# Define names for rows, columns, and slices
row_names = ["Row A", "Row B", "Row C", "Row D"]
col_names = ["Col 1", "Col 2", "Col 3", "Col 4"]
slice_names = ["Slice Alpha", "Slice Beta", "Slice Gamma", "Slice Delta"]

# Display matrix structure
print("\nMatrix Loaded!")
print("Matrix Shape:", matrix_4x4x4.shape)
print("\nMatrix Dimensions:", matrix_4x4x4.ndim)
print("\nMatrix Slices with Names:")

# Print each slice with labeled rows and columns
for i, slice_name in enumerate(slice_names):
    print(f"\n{slice_name}:\n")
    print("   " + "  ".join(col_names))
    for row_name, row_data in zip(row_names, matrix_4x4x4[i]):
        print(row_name, row_data)

# Simulate loading visualization with a progress bar
print("\nGenerating visualizations...")
for _ in tqdm(range(10), desc="Rendering"):
    sleep(0.1)  # Simulates rendering time

# Annotated Visualization
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
for slice_idx in range(matrix_4x4x4.shape[0]):
    ax = axes[slice_idx]
    cax = ax.imshow(matrix_4x4x4[slice_idx], cmap="viridis", interpolation="nearest")
    ax.set_title(f"{slice_names[slice_idx]} (Layer {slice_idx+1})")
    ax.set_xlabel("Columns")
    ax.set_ylabel("Rows")
    ax.set_xticks(range(matrix_4x4x4.shape[2]))
    ax.set_xticklabels(col_names)
    ax.set_yticks(range(matrix_4x4x4.shape[1]))
    ax.set_yticklabels(row_names)
    plt.colorbar(cax, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Loading matrix data...
# Processing: 100%|██████████| 10/10 [00:01<00:00,  9.79it/s]
# Matrix Loaded!
# Matrix Shape: (36, 1025, 11251)
#
# Matrix Dimensions: 3
#
# Matrix Slices with Names:
#
# Slice Alpha:
#
#    Col 1  Col 2  Col 3  Col 4
# Row A [-7.679061  -2.900097  -2.627634  ... -2.409874  -2.7864761 -8.214733 ]
# Row B [ -9.402079   -7.0926666  -9.312067  ...  -8.220249   -7.005766
#  -10.053875 ]
# Row C [-14.69342  -19.861544 -28.07417  ... -28.157005 -24.000463 -15.804815]
# Row D [-21.595957 -27.585962 -38.96256  ... -36.168983 -26.91758  -22.698694]
#
# Slice Beta:
#
#    Col 1  Col 2  Col 3  Col 4
# Row A [-6.9825115  -1.142952   -0.10924911 ... -0.12303543 -0.98337555
#  -6.194628  ]
# Row B [-8.511051  -5.3503685 -6.145626  ... -6.1403923 -5.5147276 -8.012251 ]
# Row C [-12.963959 -20.626163 -46.345657 ... -52.13153  -22.574455 -13.539831]
# Row D [-17.623922 -21.35595  -43.657883 ... -56.73413  -24.263971 -19.432833]
#
# Slice Gamma:
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from tqdm import tqdm

# Simulate loading process with a progress bar
print("Loading matrix data...")
for _ in tqdm(range(10), desc="Processing"):
    sleep(0.1)

# Load matrix data
try:
    matrix_4x4x4 = np.load('D:/matrix.npy')  # Replace with your actual matrix path
except FileNotFoundError:
    print("Matrix file not found. Generating a random 4x4x4 matrix.")
    matrix_4x4x4 = np.random.rand(6, 6, 6)  # Just as an example; adjust as needed

# Extract the first 4x4x4 part of the matrix
matrix_4x4x4 = matrix_4x4x4[:4, :4, :4]

# Check matrix shape
print("Extracted 4x4x4 matrix shape:", matrix_4x4x4.shape)

# Define names for rows, columns, and slices
row_names = ["Row A", "Row B", "Row C", "Row D"]
col_names = ["Col 1", "Col 2", "Col 3", "Col 4"]
slice_names = ["Slice 1", "Slice 2", "Slice 3", "Slice 4"]

# Annotated Sample Visualization
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
for slice_idx in range(matrix_4x4x4.shape[0]):
    ax = axes[slice_idx]
    cax = ax.imshow(matrix_4x4x4[slice_idx], cmap="viridis", interpolation="nearest")
    ax.set_title(f"{slice_names[slice_idx]} (Layer {slice_idx+1})")
    ax.set_xlabel("Columns")
    ax.set_ylabel("Rows")
    ax.set_xticks(range(matrix_4x4x4.shape[2]))
    ax.set_xticklabels(col_names)
    ax.set_yticks(range(matrix_4x4x4.shape[1]))
    ax.set_yticklabels(row_names)
    plt.colorbar(cax, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# Summary of structure
print("\nMatrix Structure and Data Overview:")
for slice_idx in range(matrix_4x4x4.shape[0]):
    print(f"\n{slice_names[slice_idx]} (Layer {slice_idx+1}):")
    print(matrix_4x4x4[slice_idx])
# Out:
# Loading matrix data...
# Processing: 100%|██████████| 10/10 [00:01<00:00,  9.64it/s]
# Extracted 4x4x4 matrix shape: (4, 4, 4)
# Matrix Structure and Data Overview:
#
# Slice 1 (Layer 1):
# [[ -7.679061   -2.900097   -2.627634   -2.6665459]
#  [ -9.402079   -7.0926666  -9.312067   -8.332719 ]
#  [-14.69342   -19.861544  -28.07417   -31.342484 ]
#  [-21.595957  -27.585962  -38.96256   -40.29946  ]]
#
# Slice 2 (Layer 2):
# [[ -6.9825115   -1.142952    -0.10924911  -0.12907028]
#  [ -8.511051    -5.3503685   -6.145626    -6.1417723 ]
#  [-12.963959   -20.626163   -46.345657   -48.028038  ]
#  [-17.623922   -21.35595    -43.657883   -50.662224  ]]
#
# Slice 3 (Layer 3):
# [[ -6.157219   -0.9643936  -0.1491642  -0.1592083]
#  [ -7.993717   -5.4866953  -6.1623507  -6.2016144]
#  [-13.606458  -22.655334  -59.404892  -55.324158 ]
#  [-19.620155  -24.718443  -61.112232  -61.23713  ]]
#
# Slice 4 (Layer 4):
# [[-23.438883 -17.781849 -17.389696 -17.872026]
# ...

# %%
import os
import scipy
import skimage
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
from tqdm import tqdm
import shapely
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


from sliderule import sliderule, icesat2, earthdata

import ipyleaflet
from datetime import datetime, timedelta
from shapely import Polygon

# %%
url = "slideruleearth.io"
icesat2.init(url, verbose=False)
asset = "icesat2"

# %%
# modify the following lines for custom tracks identified from Open Altimetry

target_date = '' #'2023-05-18'
target_rgt = 882 # track ID

# %%
aoi_name = 'dwarka'
aoi_data = {
    'user_defined': { 
        'target_date': target_date,
        'target_rgt': target_rgt,
        'bbox_coords': [],
    },
    'new_zealand': {
        'target_date': '2022-07-05',
        'target_rgt': 214,
        'bbox_coords': [[[172.66, -40.63],
                         [172.66, -40.47],
                         [173.14, -40.47],
                         [173.14, -40.63],
                         [172.66, -40.63]]]
    },
    'japan': {
        'target_date': '2021-10-30',
        'target_rgt': 582,
        'bbox_coords': [[[127.67, 26.16],
                         [127.67, 26.77],
                         [128.24, 26.77],
                         [128.24, 26.16],
                         [127.67, 26.16]]]
    },
    'north_carolina': {
        'target_date': '2022-06-26',
        'target_rgt': 65,
        'bbox_coords': [[[-75.87, 34.82],
                         [-75.87, 36.17],
                         [-75.19, 36.17],
                         [-75.19, 34.82],
                         [-75.87, 34.82]]]
    },
    'eritrea': {
        'target_date': '2022-09-19',
        'target_rgt': 1363,
        'bbox_coords': [[[39.90, 15.47],
                         [39.90, 16.10],
                         [40.53, 16.10],
                         [40.53, 15.47],
                         [39.90, 15.47]]]
    },
    'bahamas': {
        'target_date': '2021-07-09',
        'target_rgt': 248,
        'bbox_coords': [[[-76.8, 23.27],
                          [-76.8, 23.84],
                          [-76.22, 23.84],
                          [-76.22, 23.27],
                          [-76.8, 23.27]]]
    },
    'dwarka': {
        'target_date': '2025-01-20',  # Set the target date as required
        'target_rgt': 1234,  # Specify the relevant RGT (example: 1234)
        'bbox_coords': [[[68.952073, 22.236373, 0.0],
                         [68.969809, 22.219448, 0.0],
                         [68.972581, 22.224631, 0.0],
                         [68.970876, 22.227688, 0.0],
                         [68.965266, 22.234985, 0.0],
                         [68.960157, 22.238102, 0.0],
                         [68.95819, 22.237555, 0.0],
                         [68.956945, 22.239379, 0.0],
                         [68.952073, 22.236373, 0.0]]]
    }
}

try:
    aoi_info = aoi_data[aoi_name]
    target_date = aoi_info['target_date']
    target_rgt = aoi_info['target_rgt']
    bbox_coords = aoi_info['bbox_coords']
    
except KeyError:
    raise RuntimeError("Invalid AOI name")

# %%
# function to store any bounds drawn by the user
def handle_draw(target, action, geo_json):
    if action == 'created':
        coords = geo_json['geometry']['coordinates'][0]
        bbox_coords.append(coords)

def reverse_coordinates(bbox_coords):
    reversed_coords = []
    
    for box in bbox_coords:
        reversed_box = []
        for point in box:
            reversed_box.append([point[1], point[0]])
        reversed_coords.append(reversed_box)
    
    return reversed_coords

# setting up the map
m = ipyleaflet.Map(basemap=ipyleaflet.basemaps.Esri.WorldImagery, 
        center=(0, 0), 
        zoom=3, 
        scroll_wheel_zoom=True)

# simplifying user options - can be used to enable polygons, line drawings, etc
dc = ipyleaflet.DrawControl(circlemarker={}, polyline={})

# defining bounding box/polygon properties
custom_shape_options = {
        "fillColor": "red",
        "color": "red",
        "fillOpacity": 0.5
    }

dc.rectangle = {"shapeOptions": custom_shape_options}
dc.polygon = {"shapeOptions": custom_shape_options}

# add pre-existing bounding box to map if it exists
if aoi_name == 'user_defined':
    bbox_coords = []
    print('Draw bounding box on map below...')

else:
    poly_gdf = gpd.GeoDataFrame(geometry=[Polygon(bbox_coords[0])],
                                crs="EPSG:4326")

    m.center=(poly_gdf.geometry[0].centroid.y, poly_gdf.geometry[0].centroid.x)
    m.zoom = 8

    poly_map = ipyleaflet.Polygon(
        locations=reverse_coordinates(bbox_coords),
        color="red",
        fill_color="red"
    )

    m.add_layer(poly_map);
    
dc.on_draw(handle_draw)
m.add_control(dc)

m
# Out:
# Map(center=[22.230372830384017, 68.96333788935594], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %%
# Print the extracted information
print('AOI Name:', aoi_name.upper())
print("Target Date:", target_date)
print("Target RGT:", target_rgt)
print("Bounding Box Coordinates:\n", np.round(bbox_coords, 2))
# Out:
# AOI Name: DWARKA
# Target Date: 2025-01-20
# Target RGT: 1234
# Bounding Box Coordinates:
#  [[[68.95 22.24  0.  ]
#   [68.97 22.22  0.  ]
#   [68.97 22.22  0.  ]
#   [68.97 22.23  0.  ]
#   [68.97 22.23  0.  ]
#   [68.96 22.24  0.  ]
#   [68.96 22.24  0.  ]
#   [68.96 22.24  0.  ]
#   [68.95 22.24  0.  ]]]

# %%
# use the middle, strong beam for this demo
# for more on this, see the ATL03 user guide, or other hackweek documentation
beam_type = 'strong'
track_num = 1

# %%
# %%time

# Reformatting bounding box for query purposes
coords_arr = np.array(bbox_coords[0])  # Use only the first polygon you draw
poly = []

for point in coords_arr:
    poly.append({
        'lat': point[1],
        'lon': point[0]
    })

# Sliderule parameters for querying photon data
parms = {
    "len": 20,
    "pass_invalid": True,  # Include segments that don't pass all checks
    "cnf": -2,  # Returns all photons
    "srt": icesat2.SRT_LAND,  # Signal confidence score
    "yapc": dict(knn=0, win_h=6, win_x=11, min_ph=4, score=0),  # Density-based signal finding
    "atl03_geo_fields": ["ref_azimuth", "ref_elev", "geoid"],  # Extra fields
    "atl03_ph_fields": [],  # Additional photon fields
    "poly": poly,  # Add query polygon
}

# Formatting datetime query for demo purposes - 1 day buffer
day_window = 1  # Days on either side to query
target_dt = datetime.strptime(target_date, '%Y-%m-%d')
time_start = target_dt - timedelta(days=day_window)
time_end = target_dt + timedelta(days=day_window)

# Find granules for each region of interest
granules_list = earthdata.cmr(
    short_name='ATL03',
    polygon=poly,
    time_start=time_start.strftime('%Y-%m-%d'),
    time_end=time_end.strftime('%Y-%m-%d'),
    version='006'
)

print(granules_list)

# Create an empty GeoDataFrame using the correct function parameters
df_0 = icesat2.atl03sp(parms, resources=granules_list)
# Out:
# []
# CPU times: total: 562 ms
# Wall time: 2.13 s

# %%
# confirm that we got extra fields from ATL03 for each photon
print(f'Available photon-rate features: \n{df_0.columns.values}\n')

# inspect photon dataframe
df_0.head()
# Out:
# Available photon-rate features:
# ['geometry']
# Empty GeoDataFrame
# Columns: [geometry]
# Index: []

# %%
# %%time

# Reformatting bounding box for query purposes
coords_arr = np.array(bbox_coords[0])  # Use only the first polygon you draw
poly = []

for point in coords_arr:
    poly.append({
        'lat': point[1],
        'lon': point[0]
    })

print(f"Polygon for query: {poly}")

# Sliderule parameters for querying photon data
parms = {
    "len": 20,
    "pass_invalid": True,  # Include segments that don't pass all checks
    "cnf": -2,  # Returns all photons
    "srt": icesat2.SRT_LAND,  # Signal confidence score
    "yapc": dict(knn=0, win_h=6, win_x=11, min_ph=4, score=0),  # Density-based signal finding
    "atl03_geo_fields": ["ref_azimuth", "ref_elev", "geoid"],  # Extra fields
    "atl03_ph_fields": [],  # Additional photon fields
    "poly": poly,  # Add query polygon
}

# Formatting datetime query for demo purposes - 1 day buffer
day_window = 1  # Days on either side to query
target_dt = datetime.strptime(target_date, '%Y-%m-%d')
time_start = target_dt - timedelta(days=day_window)
time_end = target_dt + timedelta(days=day_window)

print(f"Time range: {time_start} to {time_end}")

# Find granules for each region of interest
granules_list = earthdata.cmr(
    short_name='ATL03',
    polygon=poly,
    time_start=time_start.strftime('%Y-%m-%d'),
    time_end=time_end.strftime('%Y-%m-%d'),
    version='006'
)

print(f"Granules list: {granules_list}")

if not granules_list:
    print("No granules found. Check your polygon or time range.")
else:
    # Create a GeoDataFrame using the granules list and parameters
    try:
        df_0 = icesat2.atl03sp(parms, resources=granules_list)
        print("ATL03 data successfully retrieved.")
        print(df_0.head())  # Display the first few rows of the data
    except Exception as e:
        print(f"Error retrieving ATL03 data: {e}")
# Out:
# Polygon for query: [{'lat': 22.236373, 'lon': 68.952073}, {'lat': 22.219448, 'lon': 68.969809}, {'lat': 22.224631, 'lon': 68.972581}, {'lat': 22.227688, 'lon': 68.970876}, {'lat': 22.234985, 'lon': 68.965266}, {'lat': 22.238102, 'lon': 68.960157}, {'lat': 22.237555, 'lon': 68.95819}, {'lat': 22.239379, 'lon': 68.956945}, {'lat': 22.236373, 'lon': 68.952073}]
# Time range: 2025-01-19 00:00:00 to 2025-01-21 00:00:00
# Granules list: []
# No granules found. Check your polygon or time range.
# CPU times: total: 516 ms
# Wall time: 1.71 s
